# %% [markdown]
# # <center> A Complete Guide to Regularized Regressions </center>
#
# ### <center> Support me with an upvote if you find it useful! 👍 </center>

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %% [markdown]
# ## Table of Contents
#
# <a id="toc"></a>
#
# - [1. Quick Introduction](#1)
#     - 1.1 What is regularization?
#     - 1.2 How to regularize a linear model?
#
#
# - [2. Regularization Methods](#2)
#     - 2.1 L1: Lasso Regularization
#     - 2.2 L2: Ridge Regularization
#     - 2.3 Elastic Net Regularization
#
#
# - [3. Modelling and Tuning Parameters](#3)

# %% [markdown]
# <a id="1"></a>
#
# # <center>Quick Introduction</center>

# %% [markdown]
# Have a look at this notebook [A Complete Guide to Linear Regression](https://www.kaggle.com/code/ryanluoli2/a-complete-guide-to-linear-regression) if you want to know more about linear regression models.

# %% [markdown]
# ## What is regularization?
#
# Regularization is a technique to prevent linear regression models from **`overfitting`**.
#
# For a linear model, the **complexity will be high** when there are **too many features** used. Complx models are more likely to suffer from overfitting the training data. Therefore, we need to **regularize** the model by **suppress the coefficients** of unimportant features towards zero.

# %% [markdown]
# ## How to regularize a linear model?
#
# In linear regression, we compute the best coefficients by minimizing a loss function (most commonly the **sum of squared errors**). We can add a penalty term (**sum of coefficients**) to this loss function as a **constraint** to suppress the coefficients computed.

# %% [markdown]
# ![1_2.jpg](attachment:680e722e-39fe-4831-8ea3-1dd9ea79dbe4.jpg)

# %% [markdown]
# Since the coefficients of a linear model can be either postive or negative, we need to minimize either the **absolute** or the **squared** sum of the coefficients.
#
# These are the two commonly used regularization methods:
#
# 1. **`Lasso Regularization (L1)`**: minimize the sum of the abosulute coefficients
# 2. **`Ridge Regularization (L2)`**: minimize the sum of the squared coefficients

# %% [markdown]
# <a id="2"></a>
#
# # <center>Regularization Methods</center>

# %% [markdown]
# ## L1: Lasso Regularization
#
# **`Lasso Regularization`** aims to minimize the **sum of absolute coefficients** when computing the parameters for a linear regression model:

# %% [markdown]
# ![4_2.jpg](attachment:08b4c401-2460-47ca-845e-dc13ac9ad2dd.jpg)

# %% [markdown]
# In Lasso regularization, some of the coefficients will be **suppressed to zero**. Therefore, it can also be used as a **feature selection method**.
#
# Since Lasso regularization **removes unimportant features**, it produces simpler and more interpretable linear regression models.

# %% [markdown]
# ## L2: Ridge Regularization
#
# In `Ridge Regularization`, the **sum of squared coefficeints** is minimized:

# %% [markdown]
# ![2_2.jpg](attachment:4f96524a-3e3e-49c6-8a55-91c3c50dd3bb.jpg)

# %% [markdown]
# Since Ridge regularization squares the coefficients, **larger coefficients will be suppressed more** and those that are close to zero will be barely affected. Therefore, Ridge regularization will not remove features from a linear model but will instead pruduce **many small coefficients close to zero**.
#
# Ridge regularization is more preferable when **all the features contribute a little** in predicting the output while Lasso regulariztion is better when **some features stand out** with more significant impact on the target variable.

# %% [markdown]
# ## Elastic Net Regularization

# %% [markdown]
# When **`multicolinearity`** exists among the input variables to a linear model, L1 and L2 regularizations behave differently:
#
# 1. **L1 Regularization**: one of the ocrrelated predictors will have a large coefficients while the rest will be zero.
# 2. **L2 Regularization**: coefficients of correlated predictors will be similar
#
# Why don't we **combine the two methods** if we are not sure which one is better -> **`Elastic Net`**:

# %% [markdown]
# ![3_2.jpg](attachment:8fb9e868-fd63-4a44-ac4e-4b4658a25613.jpg)

# %% [markdown]
# <a id="3"></a>
#
# # <center>Modelling and Tuning Parameters</center>

# %% [markdown]
# ## Import Data
#
# This is the data from [House Price Prediction](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques) but it has already been preprocessed (log-transform, fill missing values, encode categorical variables, drop features) and is ready to be used for modelling.

# %%
X_train = pd.read_csv('../input/cleaned-train-x/cleaned_train_X.csv')
y_train = pd.read_csv('../input/cleaned-train-y/cleaned_train_y.csv')

# %% [markdown]
# ## Evaluation Metric
#
# This is a regression problem and therefure we use **root-mean-square-error** as our evaluation metric.

# %%
def rmsle_cv(model):
    kf = KFold(5, shuffle=True, random_state=0).get_n_splits(X_train.values)
    rmse = np.sqrt(-cross_val_score(model, X_train.values, y_train, scoring="neg_mean_squared_error", cv=kf))
    return rmse

# %% [markdown]
# ## Linear Regression
#
# Linear regression uses all the features provided and is clearly suffering from **overfitting**.

# %%
#Linear regression
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_score = rmsle_cv(lr)
print(f"Linear Regression score: {round(lr_score.mean(),3)}")
# Out:
# Linear Regression score: 667968215867.886

# %% [markdown]
# ## Lasso Regression
#
# The lasso regression model in scikit-learn has a hyperparameter called **`alpha`**. This is equivalent to the lambda in the loss function demonstarted above which **controls the strength of regularization**.
#
# Here is what we will do:
#
# 1. Train a lasso regression model with the **default alpha value** (1.0)
# 2. **Tune the alpha value** with cross-validation
# 3. Train a lasso regression model with the **best alpha value**
#
# Here we use the **RobustScaler()** in combination with our lasso regression to make the model more robust to outliers.

# %%
#Lasso regression model with default alpha value
lasso = make_pipeline(RobustScaler(), Lasso(max_iter=5000, random_state=0))
lasso.fit(X_train, y_train)
lasso_score = rmsle_cv(lasso)
print(f"Lasso Regression score: {round(lasso_score.mean(),3)}")
# Out:
# Lasso Regression score: 0.386

# %%
#tune the alpha value with cross-validation
alpha_values = [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10]
for alpha in alpha_values:
    lasso = make_pipeline(RobustScaler(), Lasso(alpha=alpha, max_iter=5000, random_state=0))
    lasso.fit(X_train, y_train)
    lasso_score = rmsle_cv(lasso)
    print(f"Lasso Regression score: {round(lasso_score.mean(),3)}")
# Out:
# Lasso Regression score: 0.151
# Lasso Regression score: 0.147
# Lasso Regression score: 0.145
# Lasso Regression score: 0.142
# Lasso Regression score: 0.146
# Lasso Regression score: 0.193
# Lasso Regression score: 0.247
# Lasso Regression score: 0.377
# Lasso Regression score: 0.386
# Lasso Regression score: 0.399
# Lasso Regression score: 0.399

# %%
#use the best alpha value
lasso = make_pipeline(RobustScaler(), Lasso(alpha=0.005, max_iter=5000, random_state=0))
lasso.fit(X_train, y_train)
lasso_score = rmsle_cv(lasso)
print(f"Lasso Regression score: {round(lasso_score.mean(),3)}")
# Out:
# Lasso Regression score: 0.142

# %% [markdown]
# ## Ridge Regression
#
# Similar to above...

# %%
#Ridge regression model with default alpha value
ridge = make_pipeline(RobustScaler(), Ridge(max_iter=5000, random_state=0))
ridge.fit(X_train, y_train)
ridge_score = rmsle_cv(ridge)
print(f"Ridge Regression score: {round(ridge_score.mean(),3)}")
# Out:
# Ridge Regression score: 0.153

# %%
#tune the alpha value with cross-validation
alpha_values = [0.1, 0.5, 1, 5, 10, 15, 20, 50, 100, 200, 500, 1000]
for alpha in alpha_values:
    ridge = make_pipeline(RobustScaler(), Ridge(alpha=alpha, max_iter=5000, random_state=0))
    ridge.fit(X_train, y_train)
    ridge_score = rmsle_cv(ridge)
    print(f"ridge Regression score: {round(ridge_score.mean(),3)}")
# Out:
# ridge Regression score: 0.153
# ridge Regression score: 0.153
# ridge Regression score: 0.153
# ridge Regression score: 0.152
# ridge Regression score: 0.15
# ridge Regression score: 0.149
# ridge Regression score: 0.149
# ridge Regression score: 0.146
# ridge Regression score: 0.143
# ridge Regression score: 0.14
# ridge Regression score: 0.14
# ridge Regression score: 0.146

# %%
#use the best alpha value
ridge = make_pipeline(RobustScaler(), Ridge(alpha=200, max_iter=5000, random_state=0))
ridge.fit(X_train, y_train)
ridge_score = rmsle_cv(ridge)
print(f"Ridge Regression score: {round(ridge_score.mean(),3)}")
# Out:
# Ridge Regression score: 0.14

# %% [markdown]
# ## Elastic Net Regression
#
# In the above explanation, we have **λ1 and λ2** in the loss function controlling to the **regularization strength** of lasso and ridge respectively. These two parameters take different forms in the Elastic Net regression model provided by **scikit-learn**.
#
# The Elastic Net regression model in scikit-learn has two key parameters that controls the strength of regularization: **alpha and l1_ratio**. The relationship is:
#
# 1. alpha = λ1 + 2*λ2, default = 1.0
# 2. l1_ratio = λ1 / (λ1 + 2*λ2), default = 0.5
#
# When **l1_ratio = 1**, the Elastic Net regression model becomes a Lasso regression model. Conversely, the model becomes a Ridge regression model when **l1_ratio = 0**.

# %%
#Elastic Net regression model with default alpha value
ENet = make_pipeline(RobustScaler(), ElasticNet(max_iter=5000, random_state=0))
ENet.fit(X_train, y_train)
ENet_score = rmsle_cv(ENet)
print(f"Elastic Net Regression score: {round(ENet_score.mean(),3)}")
# Out:
# Elastic Net Regression score: 0.377

# %%
ENet_param = {'elasticnet__alpha': [0.001, 0.005, 0.01, 0.1, 0.5, 1, 5, 10],
              'elasticnet__l1_ratio': np.arange(0.1,0.9,0.1)}

ENet = make_pipeline(RobustScaler(), ElasticNet(max_iter=5000, random_state=0))
ENet_cv =  GridSearchCV(estimator=ENet, param_grid=ENet_param, 
                        scoring='neg_root_mean_squared_error', cv=5, verbose=3)
ENet_cv.fit(X_train, y_train)
ENet_cv.best_params_
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.1;, score=-0.122 total time=   0.4s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.1;, score=-0.162 total time=   0.4s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.1;, score=-0.167 total time=   0.5s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.1;, score=-0.110 total time=   0.4s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.1;, score=-0.194 total time=   0.4s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.2;, score=-0.120 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.2;, score=-0.160 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.2;, score=-0.165 total time=   0.3s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.2;, score=-0.110 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.2;, score=-0.193 total time=   0.3s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.30000000000000004;, score=-0.119 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.30000000000000004;, score=-0.159 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.30000000000000004;, score=-0.164 total time=   0.3s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.30000000000000004;, score=-0.109 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.30000000000000004;, score=-0.193 total time=   0.3s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.4;, score=-0.117 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.4;, score=-0.158 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.4;, score=-0.163 total time=   0.3s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.4;, score=-0.109 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.4;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.5;, score=-0.116 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.5;, score=-0.157 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.5;, score=-0.162 total time=   0.3s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.5;, score=-0.109 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.5;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.6;, score=-0.115 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.6;, score=-0.156 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.6;, score=-0.161 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.6;, score=-0.108 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.6;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.7000000000000001;, score=-0.115 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.7000000000000001;, score=-0.156 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.7000000000000001;, score=-0.161 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.7000000000000001;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.7000000000000001;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.8;, score=-0.114 total time=   0.4s
# [CV 2/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.8;, score=-0.155 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.8;, score=-0.160 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.8;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.001, elasticnet__l1_ratio=0.8;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.1;, score=-0.116 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.1;, score=-0.156 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.1;, score=-0.161 total time=   0.3s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.1;, score=-0.109 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.1;, score=-0.191 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.2;, score=-0.112 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.2;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.2;, score=-0.158 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.2;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.2;, score=-0.191 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.30000000000000004;, score=-0.109 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.30000000000000004;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.30000000000000004;, score=-0.155 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.30000000000000004;, score=-0.107 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.30000000000000004;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.4;, score=-0.107 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.4;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.4;, score=-0.154 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.4;, score=-0.106 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.4;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.5;, score=-0.106 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.5;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.5;, score=-0.152 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.5;, score=-0.106 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.5;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.6;, score=-0.105 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.6;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.6;, score=-0.151 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.6;, score=-0.107 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.6;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.7000000000000001;, score=-0.105 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.7000000000000001;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.7000000000000001;, score=-0.150 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.7000000000000001;, score=-0.107 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.7000000000000001;, score=-0.193 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.8;, score=-0.104 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.8;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.8;, score=-0.150 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.8;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.005, elasticnet__l1_ratio=0.8;, score=-0.193 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1;, score=-0.112 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1;, score=-0.157 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.1;, score=-0.190 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.2;, score=-0.107 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.2;, score=-0.152 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.2;, score=-0.152 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.2;, score=-0.106 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.2;, score=-0.190 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.30000000000000004;, score=-0.105 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.30000000000000004;, score=-0.152 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.30000000000000004;, score=-0.150 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.30000000000000004;, score=-0.107 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.30000000000000004;, score=-0.191 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.4;, score=-0.104 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.4;, score=-0.153 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.4;, score=-0.149 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.4;, score=-0.108 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.4;, score=-0.192 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5;, score=-0.104 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5;, score=-0.154 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5;, score=-0.148 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5;, score=-0.109 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.5;, score=-0.193 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.6;, score=-0.105 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.6;, score=-0.155 total time=   0.3s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.6;, score=-0.148 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.6;, score=-0.110 total time=   0.3s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.6;, score=-0.194 total time=   0.3s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7000000000000001;, score=-0.106 total time=   0.3s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7000000000000001;, score=-0.156 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7000000000000001;, score=-0.147 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7000000000000001;, score=-0.111 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.7000000000000001;, score=-0.195 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.8;, score=-0.108 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.8;, score=-0.157 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.8;, score=-0.147 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.8;, score=-0.112 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.01, elasticnet__l1_ratio=0.8;, score=-0.197 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1;, score=-0.113 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1;, score=-0.159 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1;, score=-0.141 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1;, score=-0.121 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.1;, score=-0.188 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.2;, score=-0.134 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.2;, score=-0.172 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.2;, score=-0.156 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.2;, score=-0.139 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.2;, score=-0.196 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.153 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.185 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.173 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.157 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.200 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.4;, score=-0.167 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.4;, score=-0.195 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.4;, score=-0.188 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.4;, score=-0.171 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.4;, score=-0.203 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5;, score=-0.181 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5;, score=-0.205 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5;, score=-0.200 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5;, score=-0.185 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.5;, score=-0.208 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.6;, score=-0.195 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.6;, score=-0.217 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.6;, score=-0.213 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.6;, score=-0.197 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.6;, score=-0.214 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.210 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.229 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.227 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.210 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.221 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.8;, score=-0.219 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.8;, score=-0.241 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.8;, score=-0.238 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.8;, score=-0.220 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.1, elasticnet__l1_ratio=0.8;, score=-0.227 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.1;, score=-0.199 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.1;, score=-0.225 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.1;, score=-0.222 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.1;, score=-0.209 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.1;, score=-0.222 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.2;, score=-0.261 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.2;, score=-0.287 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.2;, score=-0.287 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.2;, score=-0.269 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.2;, score=-0.266 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.307 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.339 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.334 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.316 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.310 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.4;, score=-0.352 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.4;, score=-0.390 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.4;, score=-0.383 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.4;, score=-0.358 total time=   0.1s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.4;, score=-0.357 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.5;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.5;, score=-0.395 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.5;, score=-0.388 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.5;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.5;, score=-0.366 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.6;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.6;, score=-0.395 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.6;, score=-0.388 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.6;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.6;, score=-0.366 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.396 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.388 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.367 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.8;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.8;, score=-0.397 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.8;, score=-0.389 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.8;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=0.5, elasticnet__l1_ratio=0.8;, score=-0.367 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.1;, score=-0.274 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.1;, score=-0.302 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.1;, score=-0.301 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.1;, score=-0.285 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.1;, score=-0.280 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.2;, score=-0.354 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.2;, score=-0.392 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.2;, score=-0.384 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.2;, score=-0.360 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.2;, score=-0.359 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.395 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.388 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.30000000000000004;, score=-0.367 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.4;, score=-0.362 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.4;, score=-0.397 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.4;, score=-0.389 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.4;, score=-0.366 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.4;, score=-0.367 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.5;, score=-0.363 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.5;, score=-0.399 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.5;, score=-0.390 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.5;, score=-0.367 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.5;, score=-0.369 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.6;, score=-0.364 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.6;, score=-0.401 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.6;, score=-0.391 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.6;, score=-0.367 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.6;, score=-0.370 total time=   0.1s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.366 total time=   0.1s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.403 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.393 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.368 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.7000000000000001;, score=-0.372 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.8;, score=-0.368 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.8;, score=-0.406 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.8;, score=-0.394 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.8;, score=-0.369 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=1, elasticnet__l1_ratio=0.8;, score=-0.373 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.1;, score=-0.364 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.1;, score=-0.400 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.1;, score=-0.390 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.1;, score=-0.367 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.1;, score=-0.369 total time=   0.1s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.2;, score=-0.373 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.2;, score=-0.412 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.2;, score=-0.398 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.2;, score=-0.372 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.2;, score=-0.378 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.382 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.30000000000000004;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.4;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.4;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.4;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.4;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.4;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.5;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.5;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.5;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.5;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.5;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.6;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.6;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.6;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.6;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.6;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.7000000000000001;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.8;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.8;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.8;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.8;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=5, elasticnet__l1_ratio=0.8;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.1;, score=-0.373 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.1;, score=-0.412 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.1;, score=-0.399 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.1;, score=-0.372 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.1;, score=-0.379 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.2;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.2;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.2;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.2;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.2;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.30000000000000004;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.30000000000000004;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.30000000000000004;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.30000000000000004;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.30000000000000004;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.4;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.4;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.4;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.4;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.4;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.5;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.5;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.5;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.5;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.5;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.6;, score=-0.387 total time=   0.1s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.6;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.6;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.6;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.6;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.7000000000000001;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.7000000000000001;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.7000000000000001;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.7000000000000001;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.7000000000000001;, score=-0.391 total time=   0.2s
# [CV 1/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.8;, score=-0.387 total time=   0.2s
# [CV 2/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.8;, score=-0.425 total time=   0.2s
# [CV 3/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.8;, score=-0.410 total time=   0.2s
# [CV 4/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.8;, score=-0.383 total time=   0.2s
# [CV 5/5] END elasticnet__alpha=10, elasticnet__l1_ratio=0.8;, score=-0.391 total time=   0.2s
# {'elasticnet__alpha': 0.01, 'elasticnet__l1_ratio': 0.30000000000000004}

# %%
#use the best alpha value
ENet = make_pipeline(RobustScaler(), ElasticNet(max_iter=5000, alpha=0.01, l1_ratio=0.3, random_state=0))
ENet.fit(X_train, y_train)
ENet_score = rmsle_cv(ENet)
print(f"Elastic Net Regression score: {round(ENet_score.mean(),3)}")
# Out:
# Elastic Net Regression score: 0.141
